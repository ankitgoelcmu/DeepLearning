# %% [markdown]
# <a href="https://colab.research.google.com/github/ankitgoelcmu/DeepLearning/blob/main/Transformer_Learnings_and_Key_Concepts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Read the paper [Attention is all you need](https://arxiv.org/abs/1706.03762). It defines the reference architecture of most LLMs. Understand following key concepts
#
#
# *   RNN + LSTM limitations [Pre-cursor to the LLMs)
# *.  Positional Encoding
# *   Self Attention [Brain of the transformer]
# *.  Multi - Headed attention
# *   Linear transformation in Self Attention
# *   Why scaling by the sq. rt of D  - the scaling factor used to stabilize the training process of the self-attention mechanism.
# *   Regularization Dropout Techniques
# *   Layer Normalization
# *  Feed Forward Netowrk

# %% [markdown]
# Youtube video to watch
# - https://youtu.be/lRylkiFdUdk?si=u2MYn9TP_ix-NfeT
# - https://youtu.be/DFqWPwF0OH0?si=z67n-n-rjjaBddVk
# - https://www.youtube.com/watch?v=viCl2T7vx64
